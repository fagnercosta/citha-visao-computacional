# %%
from ultralytics import YOLO
import cv2
from matplotlib import pyplot as plt

# Carregar o modelo
model = YOLO('yolov8n.pt')

# Caminho da imagem
imagem = "pessoas.jpg"

# Fazer a predição
results = model.predict(source=imagem, conf=0.25)

# Carregar a imagem original
image = cv2.imread(imagem)

# Verificar se a imagem foi carregada corretamente
if image is None:
    raise FileNotFoundError("Imagem não encontrada. Verifique o caminho.")

# Pegar o primeiro resultado (se houver múltiplas imagens, você pode iterar)
boxes = results[0].boxes  # caixas detectadas
names = model.names       # nomes das classes

# Desenhar as caixas
for box in boxes:
    # Coordenadas da bounding box
    x1, y1, x2, y2 = map(int, box.xyxy[0])

    # Confiança e classe
    conf = float(box.conf[0])
    cls_id = int(box.cls[0])
    label = f"{names[cls_id]}: {conf:.2f}"

    # Desenhar retângulo e texto
    cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
    cv2.putText(image, label, (x1, y1 - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

# Converter para RGB para exibir com matplotlib
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Exibir a imagem com caixas
plt.figure(figsize=(10, 6))
plt.imshow(image_rgb)
plt.axis('off')
plt.title("Objetos detectados com bounding boxes")
plt.show()
# Out:
# image 1/1 C:\Users\PC\Documents\CITHA\VisoComputacional\Exeperimentos\ExperimentosTomate\pessoas.jpg: 384x640 15 persons, 53.4ms
# Speed: 1.8ms preprocess, 53.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
model.predict(source="0", show=True, conf=0.5)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[2], line 4
#       1 from ultralytics import YOLO
#       3 model = YOLO("yolov8n.pt")
# ----> 4 model.predict(source="0", show=True, conf=0.5)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\engine\model.py:555, in Model.predict(self, source, stream, predictor, **kwargs)
#     553 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     554     self.predictor.set_prompts(prompts)
# --> 555 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\engine\predictor.py:227, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     225     return self.stream_inference(source, model, *args, **kwargs)
#     226 else:
# ...
