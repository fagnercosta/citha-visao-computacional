# %%
from ultralytics import YOLO
import cv2
import numpy as np

# Carregar o modelo treinado
model = YOLO("yolov8n_queimadas.pt")

cap = cv2.VideoCapture("video.mov") # Exemplo video.mp4
if not cap.isOpened():
	print("Erro: Não foi possível abrir a webcam")
	exit()

print("Pressione 'q' para fechar a câmera")

while True:
	ret, frame = cap.read()
	if not ret:
		print("Erro: Falha ao capturar o frame")
		break
	
	# Realizar a predição
	results = model.predict(source=frame, show=False, conf=0.1)
	
	# Obter o frame original para desenhar
	annotated_frame = frame.copy()
	
	# Verificar as detecções
	for result in results:
		boxes = result.boxes  # Caixas delimitadoras
		for box in boxes:
			# Verificar se a classe detectada é "fogo" (substitua pelo ID ou nome correto da classe do seu modelo)
			if result.names[int(box.cls)] == "fire":  # Ajuste o nome ou ID da classe conforme seu modelo
				# Obter coordenadas da caixa delimitadora
				x1, y1, x2, y2 = map(int, box.xyxy[0])
				# Desenhar retângulo vermelho no frame
				cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), (0, 0, 255), 2)
				# Adicionar rótulo com o nome da classe
				cv2.putText(annotated_frame, "Fogo", (x1, y1 - 10), 
				cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 2)
				
		# Exibir o frame com as detecções
		cv2.imshow("YOLOv8 Queimadas", annotated_frame)
		
	if cv2.waitKey(1) & 0xFF == ord('q'):
		print("Câmera fechada")
		break
# Out:
# Pressione 'q' para fechar a câmera
#
# 0: 384x640 3 fires, 56.0ms
# Speed: 2.4ms preprocess, 56.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 44.9ms
# Speed: 2.3ms preprocess, 44.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 42.0ms
# Speed: 1.6ms preprocess, 42.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 42.3ms
# Speed: 2.0ms preprocess, 42.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 43.0ms
# Speed: 1.6ms preprocess, 43.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 39.8ms
# Speed: 1.8ms preprocess, 39.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 41.5ms
# Speed: 1.6ms preprocess, 41.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 44.0ms
# Speed: 1.6ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 41.1ms
# Speed: 1.6ms preprocess, 41.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 41.7ms
# Speed: 1.5ms preprocess, 41.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 42.1ms
# Speed: 2.1ms preprocess, 42.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 40.7ms
# Speed: 1.9ms preprocess, 40.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 42.7ms
# Speed: 1.5ms preprocess, 42.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 42.5ms
# Speed: 1.6ms preprocess, 42.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 40.3ms
# Speed: 1.5ms preprocess, 40.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fires, 41.3ms
# Speed: 1.6ms preprocess, 41.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fires, 43.7ms
# Speed: 1.5ms preprocess, 43.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fires, 40.8ms
# Speed: 1.6ms preprocess, 40.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 fires, 40.8ms
# Speed: 1.7ms preprocess, 40.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fires, 40.5ms
# Speed: 1.6ms preprocess, 40.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fires, 41.1ms
# Speed: 1.6ms preprocess, 41.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 40.8ms
# Speed: 1.5ms preprocess, 40.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 42.9ms
# Speed: 1.5ms preprocess, 42.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 49.5ms
# Speed: 1.4ms preprocess, 49.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 47.3ms
# Speed: 1.8ms preprocess, 47.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 57.4ms
# Speed: 1.9ms preprocess, 57.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 48.3ms
# Speed: 1.6ms preprocess, 48.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 46.5ms
# Speed: 1.5ms preprocess, 46.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 44.1ms
# Speed: 1.7ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fires, 44.8ms
# Speed: 1.5ms preprocess, 44.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fires, 45.8ms
# Speed: 1.4ms preprocess, 45.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 42.7ms
# Speed: 1.8ms preprocess, 42.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fires, 40.4ms
# Speed: 2.0ms preprocess, 40.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fires, 40.7ms
# Speed: 1.4ms preprocess, 40.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 42.2ms
# Speed: 1.7ms preprocess, 42.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 42.5ms
# Speed: 1.6ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 41.1ms
# Speed: 1.6ms preprocess, 41.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fires, 40.8ms
# Speed: 1.5ms preprocess, 40.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 44.4ms
# Speed: 1.7ms preprocess, 44.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 47.7ms
# Speed: 1.6ms preprocess, 47.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 50.8ms
# Speed: 1.4ms preprocess, 50.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 50.7ms
# Speed: 1.4ms preprocess, 50.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 51.2ms
# Speed: 1.7ms preprocess, 51.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fires, 45.1ms
# Speed: 1.4ms preprocess, 45.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 46.9ms
# Speed: 1.4ms preprocess, 46.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 43.2ms
# Speed: 1.2ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 41.6ms
# Speed: 1.7ms preprocess, 41.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 40.8ms
# Speed: 1.4ms preprocess, 40.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 42.4ms
# Speed: 1.5ms preprocess, 42.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 41.2ms
# Speed: 1.4ms preprocess, 41.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 41.8ms
# Speed: 1.4ms preprocess, 41.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 41.1ms
# Speed: 1.5ms preprocess, 41.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 41.3ms
# Speed: 1.8ms preprocess, 41.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 45.7ms
# Speed: 1.3ms preprocess, 45.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 42.7ms
# Speed: 1.6ms preprocess, 42.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 41.1ms
# Speed: 1.5ms preprocess, 41.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 42.1ms
# Speed: 1.5ms preprocess, 42.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 41.9ms
# Speed: 1.8ms preprocess, 41.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 41.9ms
# Speed: 1.5ms preprocess, 41.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 41.3ms
# Speed: 1.4ms preprocess, 41.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 41.0ms
# Speed: 1.7ms preprocess, 41.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 61.5ms
# Speed: 1.7ms preprocess, 61.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 52.6ms
# Speed: 1.7ms preprocess, 52.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 52.0ms
# Speed: 1.5ms preprocess, 52.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 49.4ms
# Speed: 1.4ms preprocess, 49.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 52.2ms
# Speed: 1.8ms preprocess, 52.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 47.6ms
# Speed: 1.5ms preprocess, 47.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 46.3ms
# Speed: 1.4ms preprocess, 46.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 44.2ms
# Speed: 1.5ms preprocess, 44.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 43.9ms
# Speed: 1.6ms preprocess, 43.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 41.2ms
# Speed: 1.6ms preprocess, 41.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 41.8ms
# Speed: 1.3ms preprocess, 41.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 41.8ms
# Speed: 1.7ms preprocess, 41.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 41.6ms
# Speed: 1.6ms preprocess, 41.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 42.6ms
# Speed: 1.3ms preprocess, 42.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 40.4ms
# Speed: 1.6ms preprocess, 40.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 40.2ms
# Speed: 1.6ms preprocess, 40.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 40.4ms
# Speed: 1.9ms preprocess, 40.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 40.7ms
# Speed: 1.4ms preprocess, 40.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 41.2ms
# Speed: 1.6ms preprocess, 41.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 43.2ms
# Speed: 1.6ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 40.6ms
# Speed: 1.4ms preprocess, 40.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 41.2ms
# Speed: 1.9ms preprocess, 41.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 41.0ms
# Speed: 1.4ms preprocess, 41.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 39.6ms
# Speed: 1.4ms preprocess, 39.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 43.4ms
# Speed: 1.3ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 43.6ms
# Speed: 1.4ms preprocess, 43.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 41.4ms
# Speed: 1.9ms preprocess, 41.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 41.9ms
# Speed: 1.5ms preprocess, 41.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fires, 41.7ms
# Speed: 1.4ms preprocess, 41.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fires, 40.9ms
# Speed: 1.8ms preprocess, 40.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 40.7ms
# Speed: 1.4ms preprocess, 40.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 41.9ms
# Speed: 1.7ms preprocess, 41.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 41.3ms
# Speed: 1.4ms preprocess, 41.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 42.5ms
# Speed: 1.9ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 41.8ms
# Speed: 1.6ms preprocess, 41.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 41.9ms
# Speed: 1.8ms preprocess, 41.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 43.6ms
# Speed: 1.5ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 41.4ms
# Speed: 1.9ms preprocess, 41.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 45.7ms
# Speed: 1.5ms preprocess, 45.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 43.3ms
# Speed: 1.5ms preprocess, 43.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 56.2ms
# Speed: 3.0ms preprocess, 56.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 45.7ms
# Speed: 1.5ms preprocess, 45.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 46.4ms
# Speed: 1.5ms preprocess, 46.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 48.8ms
# Speed: 1.6ms preprocess, 48.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 44.8ms
# Speed: 1.7ms preprocess, 44.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.5ms
# Speed: 1.5ms preprocess, 42.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 42.8ms
# Speed: 1.6ms preprocess, 42.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 40.9ms
# Speed: 1.8ms preprocess, 40.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 40.5ms
# Speed: 1.7ms preprocess, 40.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 41.0ms
# Speed: 1.9ms preprocess, 41.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 41.4ms
# Speed: 1.9ms preprocess, 41.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fires, 41.3ms
# Speed: 1.8ms preprocess, 41.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 40.2ms
# Speed: 1.8ms preprocess, 40.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fires, 45.3ms
# Speed: 1.9ms preprocess, 45.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fires, 41.5ms
# Speed: 1.5ms preprocess, 41.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 41.5ms
# Speed: 1.9ms preprocess, 41.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 40.5ms
# Speed: 1.7ms preprocess, 40.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fires, 41.9ms
# Speed: 1.5ms preprocess, 41.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fires, 41.4ms
# Speed: 1.5ms preprocess, 41.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 40.4ms
# Speed: 1.4ms preprocess, 40.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 43.4ms
# Speed: 1.5ms preprocess, 43.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fires, 46.1ms
# Speed: 1.5ms preprocess, 46.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 43.5ms
# Speed: 1.5ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Câmera fechada
